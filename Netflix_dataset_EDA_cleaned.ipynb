# %%
#imoorting libraries
import pandas as pd

# %%
#opening file in pandas
df = pd.read_csv(r"C:\Users\sebbi\Downloads\mymoviedb (1).csv",lineterminator="\n")
df.columns = df.columns.str.strip()

# %%
#checking data via head() command
df.head()
# Out:
#   Release_Date                    Title  \
# 0   12/15/2021  Spider-Man: No Way Home
# 1     3/1/2022               The Batman
# 2    2/25/2022                  No Exit
# 3   11/24/2021                  Encanto
# 4   12/22/2021           The King's Man
#
#                                             Overview  Popularity Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954       8940
# 1  In his second year of fighting crime, Batman u...    3827.658       1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087        122
# 3  The tale of an extraordinary family, the Madri...    2402.201       5076
# 4  As a collection of history's worst tyrants and...    1895.511       1793
#
#   Vote_Average Original_Language                               Genre  \
# 0          8.3                en  Action, Adventure, Science Fiction
# 1          8.1                en            Crime, Mystery, Thriller
# ...

# %%
#checking columns and types of the fullset of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9837 entries, 0 to 9836
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9837 non-null   object
#  1   Title              9828 non-null   object
#  2   Overview           9828 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   object
#  5   Vote_Average       9827 non-null   object
#  6   Original_Language  9827 non-null   object
#  7   Genre              9826 non-null   object
#  8   Poster_Url         9837 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 691.8+ KB

# %%
 #removes Overview and Poster_Url from data set as a part of the data cleaning process.
df = df.drop(columns = ["Overview","Poster_Url"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9837 entries, 0 to 9836
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9837 non-null   object
#  1   Title              9828 non-null   object
#  2   Popularity         9827 non-null   float64
#  3   Vote_Count         9827 non-null   object
#  4   Vote_Average       9827 non-null   object
#  5   Original_Language  9827 non-null   object
#  6   Genre              9826 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 538.1+ KB

# %%
#checks for duplicates in: Title & null values in dataset
print(df.isna().sum())
print("end check for nulls")
df["Title"].duplicated().sum()
# Out:
# Release_Date          0
# Title                 9
# Popularity           10
# Vote_Count           10
# Vote_Average         10
# Original_Language    10
# Genre                11
# dtype: int64
# end check for nulls
# np.int64(322)

# %%
#Checking the duplicate dataset considering the context of this Netflix movie data set it could be the duplicates are remakes and are unique movies
check_duplicates = df[df["Title"].duplicated(keep=False)]
check_duplicates.sort_values("Title").head(50)
#confirmed that there are either sequels or remakes of movies.
# Out:
#      Release_Date                      Title  Popularity Vote_Count  \
# 3280    5/22/2015                   365 Days      28.341         12
# 1434     2/7/2020                   365 Days      52.418       6540
# 6003    10/9/1984          A Christmas Carol      18.546        241
# 2062    11/4/2009          A Christmas Carol      39.916       3732
# 2179    4/30/2010  A Nightmare on Elm Street      38.399       2187
# 1609    11/9/1984  A Nightmare on Elm Street      48.070       3877
# 3713    6/24/2016  Adventures in Babysitting      25.885        316
# 5912     7/1/1987  Adventures in Babysitting      18.722        491
# 1093     8/4/2021                  Aftermath      61.846        402
# 3576    2/28/2017                  Aftermath      26.631        725
# 9143     9/1/2016                      Akira      14.017         30
# 1521    7/16/1988                      Akira      50.144       3022
# 615     5/22/2019                    Aladdin      91.942       8421
# ...

# %%
#changing release date to datetime value, and confirming successful output: dtype('<M8[ns]')
df["Release_Date"] = pd.to_datetime(df["Release_Date"],errors='coerce')
df["Release_Date"].dtype
# Out:
# dtype('<M8[ns]')
